# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from osgeo import gdal, osr
from sklearn.linear_model import TheilSenRegressor

# %%
# Need to figure out how to get NDVI data transformed from area used in logs found at
#  https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=1288

# Plot data from https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=1288
ds = gdal.Open('./RimFire_MASTER_20140603_L3v3-NDVI.tif')
data = ds.GetRasterBand(1).ReadAsArray()
print(data.shape)
print(ds.RasterCount)
print(data[500][500])
plt.figure(figsize=(10, 10))
plt.imshow(data)
plt.colorbar()
# Out:
# (1242, 1629)
# 1
# 0.27869225
